# %% [markdown]
# Pocket matching is the process of matching pockets in difference structure of a similiar protein, for example, the apo and holo structure of a receptor. Being able to find similiar pockets enables us to find differences in the binding region from a pocket centric view.
#
# Pocket matching is based on average linkage clustering using the distance matrix generated from Jaccard distance of pocket lining atoms. The atoms are compared based on their index in the protein structure, so one needs to pre align the sequence of two proteins should they have variations in atom composition.
#
# Here is an example of how you can compute the pocket lining atom difference, using it to cluster the pockets and generated a matching table of pockets between two snapshots.
#
# First we import the alphaspace module and load the structure. from the match directory. We are using the mdm5 apo and PPI structure.

# %%
import alphaspace as al
import mdtraj
import os

# %% [markdown]
# For convenience, we pre aligned the Bcl-2 (PDB ID: 2XA0) and Bcl-xL (PDB ID: 3PL7) structures and prepared .pdbqt files for the protein part.

# %%
bcl2 = mdtraj.load("bcl/bcl2.pdb")
bclxl = mdtraj.load("bcl/bclxl.pdb")
al.annotateVinaAtomTypes(receptor=bcl2,pdbqt='bcl/bcl2.pdbqt')
al.annotateVinaAtomTypes(receptor=bclxl,pdbqt='bcl/bclxl.pdbqt')

bcl2_bax = mdtraj.load("bcl/bcl2_bax.pdb")
bclxl_bax = mdtraj.load("bcl/bclxl_bax.pdb")

ss_bcl2 = al.Snapshot()
ss_bcl2.run(bcl2, bcl2_bax)

ss_bclxl = al.Snapshot()
ss_bclxl.run(bclxl, bclxl_bax)
# Out:
# Vina Atom Type found, calculating BScore
# Vina Atom Type found, calculating BScore

# %% [markdown]
# You can remove non-overlapping atoms here like this.

# %% [markdown]
# In order to perform pocket comparison, we need to combine multiple snapshots into a Trajectory object.

# %%
bcl2_bclxl = al.Trajectory(snapshots=[ss_bcl2,ss_bclxl])

# %%
bcl2_bclxl.gen_dpockets(clust_distance=4.7)

# %% [markdown]
# Now we can iterate through d-pockets to see their attributes

# %%
for dp in bcl2_bclxl.dpockets:
    print(dp)
# Out:
# DPocket from 2 snapshots 4 beta atoms
# DPocket from 2 snapshots 7 beta atoms
# DPocket from 2 snapshots 1 beta atoms
# DPocket from 2 snapshots 5 beta atoms
# DPocket from 2 snapshots 2 beta atoms
# DPocket from 2 snapshots 5 beta atoms
# DPocket from 2 snapshots 2 beta atoms
# DPocket from 2 snapshots 9 beta atoms
# DPocket from 2 snapshots 6 beta atoms
# DPocket from 2 snapshots 5 beta atoms
# DPocket from 2 snapshots 4 beta atoms
# DPocket from 2 snapshots 8 beta atoms
# DPocket from 2 snapshots 4 beta atoms
# DPocket from 2 snapshots 1 beta atoms
# DPocket from 2 snapshots 6 beta atoms
# DPocket from 2 snapshots 7 beta atoms
# DPocket from 2 snapshots 6 beta atoms
# DPocket from 2 snapshots 6 beta atoms
# DPocket from 2 snapshots 4 beta atoms
# DPocket from 2 snapshots 7 beta atoms
# DPocket from 2 snapshots 11 beta atoms
# DPocket from 2 snapshots 6 beta atoms
# DPocket from 2 snapshots 6 beta atoms
# DPocket from 2 snapshots 7 beta atoms
# DPocket from 2 snapshots 9 beta atoms
# DPocket from 2 snapshots 4 beta atoms
# DPocket from 2 snapshots 3 beta atoms
# DPocket from 2 snapshots 6 beta atoms
# DPocket from 2 snapshots 1 beta atoms
# DPocket from 2 snapshots 2 beta atoms
# DPocket from 2 snapshots 1 beta atoms
# DPocket from 2 snapshots 3 beta atoms
# DPocket from 2 snapshots 6 beta atoms
# DPocket from 2 snapshots 8 beta atoms
# DPocket from 2 snapshots 8 beta atoms
# DPocket from 2 snapshots 7 beta atoms
# DPocket from 2 snapshots 14 beta atoms
# DPocket from 2 snapshots 7 beta atoms
# DPocket from 2 snapshots 3 beta atoms
# DPocket from 2 snapshots 6 beta atoms
# DPocket from 2 snapshots 8 beta atoms
# DPocket from 2 snapshots 6 beta atoms
# DPocket from 2 snapshots 10 beta atoms
# DPocket from 2 snapshots 9 beta atoms
# DPocket from 2 snapshots 7 beta atoms
# DPocket from 2 snapshots 9 beta atoms
# DPocket from 2 snapshots 1 beta atoms
# DPocket from 2 snapshots 1 beta atoms
# DPocket from 2 snapshots 3 beta atoms
# DPocket from 2 snapshots 12 beta atoms
# DPocket from 2 snapshots 6 beta atoms
# DPocket from 2 snapshots 13 beta atoms
# DPocket from 2 snapshots 10 beta atoms
# DPocket from 2 snapshots 3 beta atoms
# DPocket from 2 snapshots 5 beta atoms
# DPocket from 2 snapshots 2 beta atoms
# DPocket from 2 snapshots 3 beta atoms
# DPocket from 2 snapshots 2 beta atoms
# DPocket from 2 snapshots 12 beta atoms
# DPocket from 2 snapshots 5 beta atoms
# DPocket from 2 snapshots 6 beta atoms
# DPocket from 2 snapshots 1 beta atoms
# DPocket from 2 snapshots 4 beta atoms
# DPocket from 2 snapshots 4 beta atoms
# DPocket from 2 snapshots 2 beta atoms
# DPocket from 2 snapshots 3 beta atoms
# DPocket from 2 snapshots 6 beta atoms
# DPocket from 2 snapshots 8 beta atoms
# DPocket from 2 snapshots 6 beta atoms
# DPocket from 2 snapshots 4 beta atoms
# DPocket from 2 snapshots 14 beta atoms
# DPocket from 2 snapshots 3 beta atoms
# DPocket from 2 snapshots 1 beta atoms
# DPocket from 2 snapshots 6 beta atoms
# DPocket from 2 snapshots 18 beta atoms
# DPocket from 2 snapshots 7 beta atoms
# DPocket from 2 snapshots 1 beta atoms
# DPocket from 2 snapshots 5 beta atoms
# DPocket from 2 snapshots 9 beta atoms
# DPocket from 2 snapshots 4 beta atoms
# DPocket from 2 snapshots 1 beta atoms
# DPocket from 2 snapshots 4 beta atoms
# DPocket from 2 snapshots 15 beta atoms
# DPocket from 2 snapshots 5 beta atoms
# DPocket from 2 snapshots 4 beta atoms
# DPocket from 2 snapshots 5 beta atoms
# DPocket from 2 snapshots 3 beta atoms
# DPocket from 2 snapshots 12 beta atoms
# DPocket from 2 snapshots 5 beta atoms
# DPocket from 2 snapshots 7 beta atoms
# DPocket from 2 snapshots 5 beta atoms
# DPocket from 2 snapshots 5 beta atoms
# DPocket from 2 snapshots 6 beta atoms
# DPocket from 2 snapshots 13 beta atoms
# DPocket from 2 snapshots 2 beta atoms
# DPocket from 2 snapshots 6 beta atoms
# DPocket from 2 snapshots 5 beta atoms
# DPocket from 2 snapshots 8 beta atoms
# DPocket from 2 snapshots 7 beta atoms
# DPocket from 2 snapshots 6 beta atoms
# DPocket from 2 snapshots 4 beta atoms
# DPocket from 2 snapshots 6 beta atoms
# DPocket from 2 snapshots 5 beta atoms
# DPocket from 2 snapshots 8 beta atoms
# DPocket from 2 snapshots 7 beta atoms
# DPocket from 2 snapshots 22 beta atoms
# DPocket from 2 snapshots 2 beta atoms
# DPocket from 2 snapshots 18 beta atoms
# DPocket from 2 snapshots 2 beta atoms
# DPocket from 2 snapshots 13 beta atoms
# DPocket from 2 snapshots 10 beta atoms
# DPocket from 2 snapshots 5 beta atoms
# DPocket from 2 snapshots 1 beta atoms
# DPocket from 2 snapshots 5 beta atoms
# DPocket from 2 snapshots 1 beta atoms
# DPocket from 2 snapshots 1 beta atoms
# DPocket from 2 snapshots 8 beta atoms
# DPocket from 2 snapshots 10 beta atoms
# DPocket from 2 snapshots 2 beta atoms
# DPocket from 2 snapshots 8 beta atoms
# DPocket from 2 snapshots 6 beta atoms
# DPocket from 2 snapshots 7 beta atoms
# DPocket from 2 snapshots 5 beta atoms
# DPocket from 2 snapshots 2 beta atoms
# DPocket from 2 snapshots 4 beta atoms
# DPocket from 2 snapshots 2 beta atoms
# DPocket from 2 snapshots 4 beta atoms
# DPocket from 2 snapshots 4 beta atoms
# DPocket from 2 snapshots 7 beta atoms
# DPocket from 2 snapshots 6 beta atoms
# DPocket from 2 snapshots 4 beta atoms
# DPocket from 2 snapshots 3 beta atoms
# DPocket from 2 snapshots 12 beta atoms
# DPocket from 2 snapshots 2 beta atoms
# DPocket from 2 snapshots 9 beta atoms
# DPocket from 2 snapshots 4 beta atoms
# DPocket from 2 snapshots 5 beta atoms
# DPocket from 2 snapshots 21 beta atoms

# %% [markdown]
# In order to study each snapshot's contribution to the d-pocket, you can further break up d-pockets into pockets from each individual snapshots in the order they were given.

# %%
for dp in bcl2_bclxl.dpockets:
    for pocket in dp.pockets:
        print(pocket.space)
# Out:
# 24.1270815022
# 10.2022540523
# 4.71429387107
# 34.1851647245
# 12.4540901743
# 0
# 4.47999697644
# 3.83647732087
# 1.18131900672
# 1.43936625682
# 25.387923466
# 19.9251867598
# 0
# 27.7788183303
# 4.65017661918
# 51.0001925286
# 60.3328291327
# 52.5714334799
# 23.103195359
# 17.1103467001
# 17.5305744633
# 12.8000543918
# 54.1600993602
# 85.8941406477
# 13.3432218572
# 0
# 0
# 0.886377238203
# 10.0006343564
# 21.7788899899
# 45.5874779727
# 146.299833199
# 31.4253504039
# 50.0237263041
# 34.9892633967
# 18.9860519022
# 65.382716828
# 37.3085450847
# 40.5396858696
# 8.99288401706
# 122.073693201
# 151.241632178
# 86.0313551384
# 36.6127029993
# 168.572954601
# 59.0741789201
# 33.220945159
# 84.580836352
# 104.445668985
# 59.134291485
# 3.80293536
# 15.9813505306
# 16.8218463659
# 0
# 45.7093538716
# 83.0383665161
# 0.285687739961
# 0
# 15.9372254275
# 51.0270388331
# 33.6533244699
# 0
# 1.96730022435
# 1.38208793942
# 18.3673729771
# 3.28168342821
# 81.6116226488
# 39.8822086063
# 11.2845925614
# 55.3678766591
# 63.9587565674
# 17.5857149297
# 140.657459269
# 237.592230551
# 29.746631626
# 22.4524975638
# 0
# 14.8424232611
# 10.1190267014
# 6.64600904565
# 38.0512828997
# 14.1682192334
# 67.3766986001
# 9.61003941484
# 90.7276885409
# 80.1917914359
# 41.2276661373
# 70.1256511384
# 15.4597410001
# 40.9066720167
# 11.3810892799
# 45.5689689261
# 0
# 2.73877009749
# 0
# 0.490882375743
# 97.0508086029
# 0
# 12.3310031486
# 80.3739730181
# 7.0597602753
# 34.6243628301
# 38.8710295374
# 61.7191037745
# 160.612835432
# 18.3067824692
# 0
# 19.1522883251
# 16.2706573028
# 3.61800644896
# 5.74814213905
# 0.627549132332
# 9.55330370925
# 0
# 1.0478385957
# 1.03344078525
# 45.6547373324
# 72.7857861202
# 3.4498667228
# 13.7677172897
# 3.21276625618
# 30.0334766507
# 0
# 4.71689458936
# 18.7622735975
# 4.9125731457
# 14.7609931882
# 48.4955432476
# 0
# 101.603301242
# 58.5836330429
# 50.9474548744
# 10.8429032261
# 6.71908509685
# 41.6825514112
# 8.93663527677
# 45.2837445773
# 12.5612496631
# 7.74159329012
# 18.1795611861
# 148.599839111
# 24.3935645558
# 18.2838805486
# 0.606211015793
# 0
# 1.80805847049
# 44.2985622212
# 66.0265190527
# 264.917724358
# 271.033213008
# 2.32444007997
# 4.38336972729
# 2.18101404607
# 0
# 38.2841106039
# 29.9806052353
# 26.6526791966
# 37.579468044
# 21.0988020117
# 21.4843284339
# 5.20492671058
# 0
# 3.29837482423
# 4.79330378585
# 120.636489708
# 130.072144384
# 0.485271836169
# 2.29398877127
# 7.11294985376
# 8.32573266234
# 14.2658815603
# 17.9641169962
# 11.95028238
# 4.00081602857
# 186.851657461
# 126.610148815
# 47.7054681978
# 67.5742651802
# 171.248567407
# 39.8106081411
# 14.6121396683
# 37.8338363953
# 31.0659226379
# 8.99027785636
# 42.1094730264
# 36.080594291
# 218.241746828
# 136.703752913
# 0.967456726357
# 1.15331806592
# 28.0249423813
# 27.122239524
# 13.1994488183
# 18.092313956
# 22.7631811285
# 86.3244123757
# 32.2115244053
# 7.11108441465
# 8.0114758166
# 4.73700955627
# 75.8781319018
# 0
# 23.5950196802
# 42.4374376889
# 3.26368585229
# 53.3137030434
# 24.4459290407
# 19.6945988573
# 7.81678504427
# 24.8139982577
# 89.5494364959
# 303.629055852
# 65.9312610514
# 0
# 189.341278572
# 455.17704566
# 22.4891942926
# 0
# 91.0144241352
# 52.242049831
# 3.00572198466
# 28.6824097857
# 0.724486773834
# 28.2863389002
# 13.6719807051
# 0
# 0
# 55.5683004204
# 2.26722774096
# 0
# 1.15375334281
# 0
# 4.56863868749
# 61.3638649229
# 59.6353509463
# 25.3839343495
# 0
# 7.53900769632
# 26.2239548028
# 30.1488598925
# 18.8914096216
# 13.7257600545
# 47.5420498988
# 36.773881875
# 20.7223955076
# 0.494409934618
# 1.34989060462
# 1.07723311521
# 20.1659658924
# 1.86004093848
# 1.65246683173
# 0.77621062519
# 38.1810610997
# 0
# 0
# 71.7565324157
# 54.4434571639
# 26.9124188926
# 20.6047010142
# 50.4932399344
# 17.5468547095
# 0
# 6.82804360986
# 3.2820112292
# 33.7992682762
# 31.6909934627
# 5.89710799977
# 0
# 90.2512726898
# 61.2296620384
# 114.807398757
# 22.7998625487
# 15.7048306428
# 53.7040448398
# 315.559443145
# 293.686908437
